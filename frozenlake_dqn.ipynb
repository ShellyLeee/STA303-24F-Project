# %% [markdown]
# # DQN Algorithm Implementation
#
# This notebook is the basic implementation of DQN. It contains two parts:
# - Run the model with defailt parameters
# - Hyperparameters tuning

# %% [markdown]
# ## 1. Run the model with defailt parameters
# In this part, besides the given basic visulization, we add a plot to show the variance of reward as the number of episodes increase.

# %%
# !pip install -r requirements.txt
# Out:
# Collecting tqdm==4.66.5 (from -r requirements.txt (line 1))
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting matplotlib==3.7.5 (from -r requirements.txt (line 2))
#   Using cached matplotlib-3.7.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.7 kB)
# Collecting pandas==1.5.3 (from -r requirements.txt (line 3))
#   Using cached pandas-1.5.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting gymnasium==0.29.1 (from -r requirements.txt (line 4))
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting numpy==1.22.0 (from -r requirements.txt (line 5))
#   Using cached numpy-1.22.0-cp311-cp311-macosx_12_0_arm64.whl
# Collecting pygame==2.5.2 (from -r requirements.txt (line 6))
#   Using cached pygame-2.5.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from pandas==1.5.3->-r requirements.txt (line 3)) (2024.1)
# INFO: pip is looking at multiple versions of pandas to determine which version is compatible with other requirements. This could take a while.
# ERROR: Cannot install -r requirements.txt (line 2), -r requirements.txt (line 3) and numpy==1.22.0 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested numpy==1.22.0
#     matplotlib 3.7.5 depends on numpy<2 and >=1.20
#     pandas 1.5.3 depends on numpy>=1.21.0; python_version >= "3.10"
#     pandas 1.5.3 depends on numpy>=1.23.2; python_version >= "3.11"
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts

# %%
# Import necessary modules
import os
import gc
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt
import gymnasium as gym
from agent.base_agent import BaseAgent
from utils import seed_everything

# Set device to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Environment setup
gc.collect()
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'  # Set CUDA launch blocking to 1 for debugging CUDA-related errors


# Replay Buffer Class
class ReplayBuffer:
    def __init__(self, capacity):
        """
        Experience replay buffer used to store transitions
        """
        self.capacity = capacity
        self.buffer = deque(maxlen=capacity)

    def store(self, state, action, next_state, reward, done):
        """
        Store a transition in the buffer
        """
        self.buffer.append((state, action, next_state, reward, done))

    def sample(self, batch_size):
        """
        Randomly sample a batch of transitions from the buffer
        """
        indices = np.random.choice(len(self.buffer), size=batch_size, replace=False)
        states, actions, next_states, rewards, dones = zip(*(self.buffer[idx] for idx in indices))

        # Convert sampled transitions to tensors
        states = torch.stack(states).to(device)
        actions = torch.tensor(actions, dtype=torch.long, device=device)
        next_states = torch.stack(next_states).to(device)
        rewards = torch.tensor(rewards, dtype=torch.float32, device=device)
        dones = torch.tensor(dones, dtype=torch.bool, device=device)

        return states, actions, next_states, rewards, dones

    def __len__(self):
        return len(self.buffer)

class Qnet(nn.Module):
    def __init__(self, num_actions, input_dim):
        """
        Neural network for Deep Q-Learning
        """
        super(Qnet, self).__init__()
        self.fc_layers = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(64, 32),
            nn.ReLU(inplace=True),
            nn.Linear(32, num_actions)
        )
        self._initialize_weights()

    def forward(self, x):
        """
        Forward pass through the network
        """
        return self.fc_layers(x)


    def _initialize_weights(self):
        """
        Initialize weights for linear layers using Kaiming uniform initialization
        """
        for layer in self.fc_layers:
            if isinstance(layer, nn.Linear):
                nn.init.kaiming_uniform_(layer.weight, nonlinearity='relu')


# DQN Agent Class inheriting from Agent
class DQNAgent(BaseAgent):
    def __init__(self, env, hyperparams):
        """
        DQN Agent class for interacting with the environment and learning
        """
        super(DQNAgent, self).__init__(env, hyperparams)
        self.replay_memory = ReplayBuffer(hyperparams['memory_capacity'])

        # Main and target networks
        self.model = Qnet(self.num_actions, self.state_dim).to(device)
        self.target_network = Qnet(self.num_actions, self.state_dim).to(device)
        self.update_target_network()

        # Optimizer and loss function
        self.optimizer = optim.Adam(self.model.parameters(), lr=hyperparams['learning_rate'])
        self.criterion = nn.MSELoss()
        
        # Additional hyperparameters
        self.discount = hyperparams['discount_factor']
        self.epsilon = hyperparams['epsilon_max']
        self.epsilon_min = hyperparams['epsilon_min']
        self.epsilon_decay = hyperparams['epsilon_decay']
        self.clip_grad_norm = hyperparams['clip_grad_norm']
        self.loss_history = []
        self.running_loss = 0
        self.learned_counts = 0

    def select_action(self, state):
        """
        Select an action using epsilon-greedy policy
        """
        if np.random.random() < self.epsilon:
            return self.env.action_space.sample()
        with torch.no_grad():
            Q_values = self.model(state)
            return torch.argmax(Q_values).item()

    def learn(self, batch_size, done):
        """
        Learn from a batch of experiences using the DQN update rule
        """
        # Sample a batch from the replay buffer
        states, actions, next_states, rewards, dones = self.replay_memory.sample(batch_size)
        actions = actions.unsqueeze(1)
        rewards = rewards.unsqueeze(1)
        dones = dones.unsqueeze(1)
        # Compute predicted Q-values and target Q-values
        predicted_q = self.model(states).gather(dim=1, index=actions)
        with torch.no_grad():
            next_target_q_value = self.target_network(next_states).max(dim=1, keepdim=True)[0]
        next_target_q_value[dones] = 0
        y_js = rewards + (self.discount * next_target_q_value)
        # Compute loss
        loss = self.criterion(predicted_q, y_js)
        self.running_loss += loss.item()
        self.learned_counts += 1
        if done:
            self.loss_history.append(self.running_loss / self.learned_counts)
            self.running_loss, self.learned_counts = 0, 0
        # Backpropagate the loss
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.clip_grad_norm)
        self.optimizer.step()

    def update_target_network(self):
        """
        Update the target network by copying weights from the main network
        """
        self.target_network.load_state_dict(self.model.state_dict())

    def update_epsilon(self):
        """
        Update epsilon value for epsilon-greedy policy
        """
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def save(self, path):
        """
        Save the trained model
        """
        torch.save(self.model.state_dict(), path)
    
    def load(self, path):
        """
        Load the trained model
        """
        self.model.load_state_dict(torch.load(path, map_location=device))

# Trainer Class
class Trainer:
    def __init__(self, env, agent, hyperparams):
        """
        Trainer class to manage training and evaluation of the agent
        """
        self.env = env
        self.agent = agent
        self.hyperparams = hyperparams
        self.reward_history = []
        self.step_history = []
        self.variance_history = []

        if hasattr(agent, 'replay_memory'):
            self.use_replay_memory = True
        else:
            self.use_replay_memory = False

    def state_preprocess(self, state):
        """
        Convert the state to one-hot representation 
        """
        onehot_vector = torch.zeros(self.env.observation_space.n, dtype=torch.float32, device=device)
        onehot_vector[state] = 1
        return onehot_vector

    def train(self):
        """
        Train the agent for a specified number of episodes
        """
        total_steps = 0
        standard_value = 0.66  # Standard value to compare rewards

        for episode in range(1, self.hyperparams['max_episodes'] + 1):
            state, _ = self.env.reset(seed=seed)
            state = self.state_preprocess(state)
            done, truncation = False, False
            step_size, episode_reward = 0, 0

            while not done and not truncation:
                # Select and execute an action
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)
                next_state = self.state_preprocess(next_state)

                # use ReplayBuffer
                if self.use_replay_memory:
                    self.agent.replay_memory.store(state, action, next_state, reward, done)
                    if len(self.agent.replay_memory) > self.hyperparams['batch_size'] and sum(self.reward_history) > 0:
                        self.agent.learn(self.hyperparams['batch_size'], (done or truncation))
                        # Update target network periodically
                        if total_steps % self.hyperparams['update_frequency'] == 0:
                            self.agent.update_target_network()

                state = next_state
                episode_reward += reward
                step_size += 1

            self.reward_history.append(episode_reward)
            self.step_history.append(step_size)  # Track steps for each episode
            total_steps += step_size
            self.agent.update_epsilon()



            # Calculate the variance between current episode's reward and the standard value
            variance = (episode_reward - standard_value) ** 2
            self.variance_history.append(variance)
           
           
            # Save the model at specified intervals
            if episode % self.hyperparams['save_interval'] == 0:
                os.makedirs(self.hyperparams['model_dir'], exist_ok=True)
                self.agent.save(os.path.join(self.hyperparams['model_dir'], f'{episode}.pth'))
                print('\n~~~~~~Interval Save: Model saved.\n')
            # Print episode information at specified intervals
            if episode % self.hyperparams['print_interval'] == 0:
                print(f"Episode: {episode}, Total Steps: {total_steps}, Ep Step: {step_size}, Raw Reward: {episode_reward:.2f}, Epsilon: {self.agent.epsilon:.2f}")
        
        # Calculate the average reward of the last 100 episodes
        last_100_rewards = self.reward_history[-100:]
        avg_100 = np.mean(last_100_rewards)
        print(f"Average reward of the last 100 episodes: {avg_100:.2f}")

        self.plot_training(episode)

    def test(self, max_episodes=None):
        """
        Test the trained agent
        """
        # Load the trained model
        self.agent.load(os.path.join(self.hyperparams['model_dir'], f"{self.hyperparams['train_episodes']}.pth"))
        self.agent.model.eval()

        if max_episodes is None:
            max_episodes = self.hyperparams['max_episodes']

        for episode in range(1, max_episodes + 1):
            state, _ = self.env.reset(seed=seed)
            done, truncation = False, False
            step_size, episode_reward = 0, 0

            while not done and not truncation:
                # Select an action
                state = self.state_preprocess(state)
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)
                state = next_state
                episode_reward += reward
                step_size += 1

            # Print episode information
            print(f"Episode: {episode}, Steps: {step_size}, Reward: {episode_reward:.2f}")




    def moving_average(self, data, window_size):
        """
        Compute the simple moving average (SMA) of a list of numbers
        """
        return np.convolve(data, np.ones(window_size) / window_size, mode='valid')



    def plot_training(self, episode):
        """
        Plot the training reward history, loss history, and step convergence
        """
        # Plot Rewards
        sma = np.convolve(self.reward_history, np.ones(50)/50, mode='valid')
        plt.figure()
        plt.title("Rewards")
        plt.plot(self.reward_history, label='Raw Reward', color='#F6CE3B', alpha=1)
        plt.plot(sma, label='SMA 50', color='#385DAA')
        plt.xlabel("Episode")
        plt.ylabel("Rewards")
        plt.legend()
        if episode == self.hyperparams['max_episodes']:
            os.makedirs(self.hyperparams['plot_dir'], exist_ok=True)
            plt.savefig(os.path.join(self.hyperparams['plot_dir'], 'reward_plot.png'), format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()

        # Plot Loss
        plt.figure()
        plt.title("Loss")
        plt.plot(self.agent.loss_history, label='Loss', color='#CB291A', alpha=1)
        plt.xlabel("Episode")
        plt.ylabel("Loss")
        if episode == self.hyperparams['max_episodes']:
            plt.savefig(os.path.join(self.hyperparams['plot_dir'], 'loss_plot.png'), format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()

        # Plot Steps Convergence
        sma_steps = np.convolve(self.step_history, np.ones(50)/50, mode='valid')
        plt.figure()
        plt.title("Steps Convergence")
        plt.plot(self.step_history, label='Raw Steps', color='#4CAF50', alpha=1)
        plt.plot(sma_steps, label='SMA 50', color='#FF5733')
        plt.xlabel("Episode")
        plt.ylabel("Steps")
        plt.legend()
        if episode == self.hyperparams['max_episodes']:
            plt.savefig(os.path.join(self.hyperparams['plot_dir'], 'steps_plot.png'), format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()

        # Plot Reward Variance for the last 100 episodes
        last_100_rewards = self.reward_history[-100:]  # 获取最近100个episode的奖励
        reward_variance_last_100 = [np.var(last_100_rewards[:i+1]) for i in range(len(last_100_rewards))]  # 计算最近100个episode的奖励方差

        plt.figure()
        plt.title("Reward Variance (Last 100 Episodes)")
        plt.plot(range(len(reward_variance_last_100)), reward_variance_last_100, label='Reward Variance (Last 100 Episodes)', color='red')
        plt.xlabel("Episode")
        plt.ylabel("Reward Variance")
        plt.legend()
        if episode == self.hyperparams['max_episodes']:
            plt.savefig(os.path.join(self.hyperparams['plot_dir'], 'reward_variance_last_100_plot.png'), format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()


# Main Function to Set Up and Train/Test the Model
if __name__ == "__main__":
    method_name = "dqn"
    train_mode = True

    train_episodes = 10000
    render = not train_mode
    map_size = 4 # Start with 4x4 map
    seed = 1

    # build config
    config = {
        "train_mode": train_mode,
        "method_name": method_name,
        "model_dir": f'output/{method_name}/model/{map_size}x{map_size}/',
        "plot_dir": f'output/{method_name}/plt/{map_size}x{map_size}/',
        "save_interval": 500,
        "print_interval": 100,
        "clip_grad_norm": 3,
        "learning_rate": 6e-4,
        "discount_factor": 0.93,
        "batch_size": 32,
        "update_frequency": 10,
        "max_episodes": train_episodes if train_mode else 10,
        "train_episodes": train_episodes,
        "max_steps": 200,
        "render": render,
        "epsilon_max": 0.999 if train_mode else -1,
        "epsilon_min": 0.01,
        "epsilon_decay": 0.999,
        "memory_capacity": 4000 if train_mode else 0,
        "map_size": map_size,
        "render_fps": 6,
    }

    # set seed
    seed_everything(seed)

    # Create environment
    env = gym.make(
        'FrozenLake-v1', 
        map_name=f"{config['map_size']}x{config['map_size']}", 
        is_slippery=True, 
        max_episode_steps=config['max_steps'], 
        render_mode="human" if config['render'] else None)

    env.reset(seed=seed)
    env.action_space.seed(seed)
    env.metadata['render_fps'] = config['render_fps']

    # Create agent and trainer
    agent = DQNAgent(env, config)
    trainer = Trainer(env, agent, config)

    # Train or test
    if config['train_mode']:
        trainer.train()
    else:
        trainer.test()
# Out:
# Episode: 100, Total Steps: 703, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.90
# Episode: 200, Total Steps: 1458, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.82
# Episode: 300, Total Steps: 2394, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.74
# Episode: 400, Total Steps: 3360, Ep Step: 22, Raw Reward: 0.00, Epsilon: 0.67
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 500, Total Steps: 4420, Ep Step: 17, Raw Reward: 0.00, Epsilon: 0.61
# Episode: 600, Total Steps: 5290, Ep Step: 33, Raw Reward: 0.00, Epsilon: 0.55
# Episode: 700, Total Steps: 6192, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.50
# Episode: 800, Total Steps: 7274, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.45
# Episode: 900, Total Steps: 8448, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.41
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1000, Total Steps: 9529, Ep Step: 11, Raw Reward: 1.00, Epsilon: 0.37
# Episode: 1100, Total Steps: 10585, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.33
# Episode: 1200, Total Steps: 11906, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.30
# Episode: 1300, Total Steps: 13284, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.27
# Episode: 1400, Total Steps: 14444, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.25
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1500, Total Steps: 15676, Ep Step: 16, Raw Reward: 1.00, Epsilon: 0.22
# Episode: 1600, Total Steps: 17091, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.20
# Episode: 1700, Total Steps: 18742, Ep Step: 18, Raw Reward: 0.00, Epsilon: 0.18
# Episode: 1800, Total Steps: 20186, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.16
# Episode: 1900, Total Steps: 21622, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.15
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2000, Total Steps: 23275, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.14
# Episode: 2100, Total Steps: 24723, Ep Step: 16, Raw Reward: 1.00, Epsilon: 0.12
# Episode: 2200, Total Steps: 26373, Ep Step: 17, Raw Reward: 0.00, Epsilon: 0.11
# Episode: 2300, Total Steps: 27964, Ep Step: 24, Raw Reward: 0.00, Epsilon: 0.10
# Episode: 2400, Total Steps: 29158, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.09
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2500, Total Steps: 31039, Ep Step: 25, Raw Reward: 0.00, Epsilon: 0.08
# Episode: 2600, Total Steps: 33271, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.07
# Episode: 2700, Total Steps: 35359, Ep Step: 25, Raw Reward: 0.00, Epsilon: 0.07
# Episode: 2800, Total Steps: 37384, Ep Step: 52, Raw Reward: 1.00, Epsilon: 0.06
# Episode: 2900, Total Steps: 39018, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.05
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3000, Total Steps: 41036, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.05
# Episode: 3100, Total Steps: 43396, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.04
# Episode: 3200, Total Steps: 45561, Ep Step: 25, Raw Reward: 0.00, Epsilon: 0.04
# Episode: 3300, Total Steps: 47459, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.04
# Episode: 3400, Total Steps: 49028, Ep Step: 51, Raw Reward: 0.00, Epsilon: 0.03
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3500, Total Steps: 50764, Ep Step: 15, Raw Reward: 0.00, Epsilon: 0.03
# Episode: 3600, Total Steps: 52953, Ep Step: 17, Raw Reward: 0.00, Epsilon: 0.03
# Episode: 3700, Total Steps: 55414, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3800, Total Steps: 58132, Ep Step: 37, Raw Reward: 0.00, Epsilon: 0.02
# Episode: 3900, Total Steps: 60809, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.02
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4000, Total Steps: 62895, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 4100, Total Steps: 64842, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 4200, Total Steps: 67113, Ep Step: 45, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4300, Total Steps: 69624, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4400, Total Steps: 71731, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4500, Total Steps: 72845, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4600, Total Steps: 74053, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4700, Total Steps: 75115, Ep Step: 26, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4800, Total Steps: 76548, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4900, Total Steps: 79155, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5000, Total Steps: 81942, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5100, Total Steps: 83330, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5200, Total Steps: 84691, Ep Step: 18, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5300, Total Steps: 86660, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5400, Total Steps: 88766, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5500, Total Steps: 91458, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5600, Total Steps: 94223, Ep Step: 75, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5700, Total Steps: 97319, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5800, Total Steps: 99412, Ep Step: 26, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5900, Total Steps: 102280, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6000, Total Steps: 104612, Ep Step: 20, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6100, Total Steps: 107295, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6200, Total Steps: 109963, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6300, Total Steps: 112251, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6400, Total Steps: 115001, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6500, Total Steps: 116745, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6600, Total Steps: 117706, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6700, Total Steps: 119414, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6800, Total Steps: 121637, Ep Step: 40, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6900, Total Steps: 124243, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7000, Total Steps: 127097, Ep Step: 33, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7100, Total Steps: 129544, Ep Step: 15, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7200, Total Steps: 131867, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7300, Total Steps: 133415, Ep Step: 81, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7400, Total Steps: 136202, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7500, Total Steps: 138615, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7600, Total Steps: 139546, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7700, Total Steps: 140658, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7800, Total Steps: 142445, Ep Step: 37, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7900, Total Steps: 144914, Ep Step: 15, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8000, Total Steps: 146930, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8100, Total Steps: 150152, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8200, Total Steps: 151713, Ep Step: 10, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8300, Total Steps: 153397, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8400, Total Steps: 155868, Ep Step: 31, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8500, Total Steps: 158851, Ep Step: 52, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8600, Total Steps: 161674, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8700, Total Steps: 164523, Ep Step: 23, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8800, Total Steps: 166479, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8900, Total Steps: 168659, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9000, Total Steps: 170965, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9100, Total Steps: 173899, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9200, Total Steps: 175379, Ep Step: 10, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9300, Total Steps: 177323, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9400, Total Steps: 180602, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9500, Total Steps: 182591, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9600, Total Steps: 185535, Ep Step: 60, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9700, Total Steps: 188318, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9800, Total Steps: 190304, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9900, Total Steps: 192086, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 10000, Total Steps: 194590, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.01
# Average reward of the last 100 episodes: 0.66

# %% [markdown]
# ## 2. Hyperparameters tuning

# %%
import numpy as np
import itertools

# Parameter names and search spaces
param_names = ["epsilon_max"]
param_values = [np.arange(0.78, 0.82, 0.01)]  # Parameters a、b、c: Search from a to b，with an increase c each time
param_combinations = list(itertools.product(*param_values))

results = []

for params in param_combinations:
    # Unpack parameters
    hyperparams = dict(zip(param_names, params))
    print(f"Training with hyperparams: {hyperparams}")

    # Update configuration
    config.update(hyperparams)

     # Set seed
    seed_everything(seed)

    # Create environment
    env = gym.make(
        'FrozenLake-v1', 
        map_name=f"{config['map_size']}x{config['map_size']}", 
        is_slippery=True, 
        max_episode_steps=config['max_steps'], 
        render_mode="human" if config['render'] else None)

    env.reset(seed=seed)
    env.action_space.seed(seed)
    env.metadata['render_fps'] = config['render_fps']

    agent = DQNAgent(env, config)
    trainer = Trainer(env, agent, config)

    trainer.train()

    # Calculate the average reward for the last 100 episodes
    avg_reward = np.mean(trainer.reward_history[-100:])

    # Calculate the variance of the reward in last 100 episodes
    reward_variance = np.var(trainer.reward_history[-100:]) 

    # Record result
    results.append((hyperparams, avg_reward, reward_variance))
    results.append((hyperparams, avg_reward))

# Print the best combination of hyperparameters and the corresponding mean reward and reward variance
best_params = max(results, key=lambda x: x[1])
best_avg_reward, best_variance = best_params[1], best_params[2]
print(f"Best hyperparams: {best_params[0]} with average reward: {best_avg_reward:.2f} and reward variance: {best_variance:.2f}")
# Out:
# Training with hyperparams: {'epsilon_max': 0.78}
# Episode: 100, Total Steps: 772, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.71
# Episode: 200, Total Steps: 1594, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.64
# Episode: 300, Total Steps: 2584, Ep Step: 13, Raw Reward: 0.00, Epsilon: 0.58
# Episode: 400, Total Steps: 3584, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.52
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 500, Total Steps: 4725, Ep Step: 26, Raw Reward: 0.00, Epsilon: 0.47
# Episode: 600, Total Steps: 5669, Ep Step: 15, Raw Reward: 1.00, Epsilon: 0.43
# Episode: 700, Total Steps: 6659, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.39
# Episode: 800, Total Steps: 7791, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.35
# Episode: 900, Total Steps: 8898, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.32
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1000, Total Steps: 10103, Ep Step: 10, Raw Reward: 0.00, Epsilon: 0.29
# Episode: 1100, Total Steps: 11595, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.26
# Episode: 1200, Total Steps: 12892, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.23
# Episode: 1300, Total Steps: 14172, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.21
# Episode: 1400, Total Steps: 15804, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.19
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1500, Total Steps: 17714, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.17
# Episode: 1600, Total Steps: 19175, Ep Step: 25, Raw Reward: 0.00, Epsilon: 0.16
# Episode: 1700, Total Steps: 20691, Ep Step: 15, Raw Reward: 0.00, Epsilon: 0.14
# Episode: 1800, Total Steps: 22073, Ep Step: 16, Raw Reward: 1.00, Epsilon: 0.13
# Episode: 1900, Total Steps: 23243, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.12
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2000, Total Steps: 24483, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.11
# Episode: 2100, Total Steps: 26005, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.10
# Episode: 2200, Total Steps: 27769, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.09
# Episode: 2300, Total Steps: 29407, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.08
# Episode: 2400, Total Steps: 31033, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.07
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2500, Total Steps: 32709, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.06
# Episode: 2600, Total Steps: 34390, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.06
# Episode: 2700, Total Steps: 36204, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.05
# Episode: 2800, Total Steps: 38438, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.05
# Episode: 2900, Total Steps: 40156, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.04
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3000, Total Steps: 41476, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.04
# Episode: 3100, Total Steps: 43267, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.04
# Episode: 3200, Total Steps: 44900, Ep Step: 18, Raw Reward: 0.00, Epsilon: 0.03
# Episode: 3300, Total Steps: 47298, Ep Step: 9, Raw Reward: 0.00, Epsilon: 0.03
# Episode: 3400, Total Steps: 48336, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.03
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3500, Total Steps: 49516, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.02
# Episode: 3600, Total Steps: 50833, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.02
# Episode: 3700, Total Steps: 52164, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.02
# Episode: 3800, Total Steps: 54550, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3900, Total Steps: 57130, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.02
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4000, Total Steps: 60000, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4100, Total Steps: 61948, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4200, Total Steps: 64465, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4300, Total Steps: 66490, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4400, Total Steps: 68323, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4500, Total Steps: 70091, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4600, Total Steps: 71635, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4700, Total Steps: 72873, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4800, Total Steps: 73848, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4900, Total Steps: 74765, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5000, Total Steps: 75755, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5100, Total Steps: 76677, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5200, Total Steps: 77681, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5300, Total Steps: 78672, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5400, Total Steps: 79683, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5500, Total Steps: 80614, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5600, Total Steps: 81573, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5700, Total Steps: 82529, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5800, Total Steps: 83465, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5900, Total Steps: 84379, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6000, Total Steps: 85350, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6100, Total Steps: 86361, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6200, Total Steps: 87428, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6300, Total Steps: 88345, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6400, Total Steps: 89261, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6500, Total Steps: 90152, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6600, Total Steps: 91162, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6700, Total Steps: 92205, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6800, Total Steps: 93131, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6900, Total Steps: 94180, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7000, Total Steps: 95184, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7100, Total Steps: 96238, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7200, Total Steps: 97264, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7300, Total Steps: 98338, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7400, Total Steps: 99401, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7500, Total Steps: 100308, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7600, Total Steps: 101232, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7700, Total Steps: 102200, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7800, Total Steps: 103148, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7900, Total Steps: 104097, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8000, Total Steps: 105009, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8100, Total Steps: 105911, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8200, Total Steps: 106830, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8300, Total Steps: 107777, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8400, Total Steps: 108697, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8500, Total Steps: 109658, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8600, Total Steps: 110450, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8700, Total Steps: 111444, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8800, Total Steps: 112395, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8900, Total Steps: 113274, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9000, Total Steps: 114106, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9100, Total Steps: 115006, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9200, Total Steps: 115802, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9300, Total Steps: 116697, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9400, Total Steps: 117554, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9500, Total Steps: 118377, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9600, Total Steps: 119166, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9700, Total Steps: 120034, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9800, Total Steps: 120879, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9900, Total Steps: 121743, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 10000, Total Steps: 122549, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Average reward of the last 100 episodes: 0.45
# Training with hyperparams: {'epsilon_max': 0.79}
# Episode: 100, Total Steps: 730, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.71
# Episode: 200, Total Steps: 1612, Ep Step: 2, Raw Reward: 0.00, Epsilon: 0.65
# Episode: 300, Total Steps: 2641, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.59
# Episode: 400, Total Steps: 3752, Ep Step: 2, Raw Reward: 0.00, Epsilon: 0.53
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 500, Total Steps: 4955, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.48
# Episode: 600, Total Steps: 5931, Ep Step: 9, Raw Reward: 0.00, Epsilon: 0.43
# Episode: 700, Total Steps: 6899, Ep Step: 2, Raw Reward: 0.00, Epsilon: 0.39
# Episode: 800, Total Steps: 7879, Ep Step: 9, Raw Reward: 0.00, Epsilon: 0.35
# Episode: 900, Total Steps: 9073, Ep Step: 10, Raw Reward: 1.00, Epsilon: 0.32
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1000, Total Steps: 10300, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.29
# Episode: 1100, Total Steps: 11751, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.26
# Episode: 1200, Total Steps: 13350, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.24
# Episode: 1300, Total Steps: 14807, Ep Step: 13, Raw Reward: 1.00, Epsilon: 0.22
# Episode: 1400, Total Steps: 16198, Ep Step: 25, Raw Reward: 0.00, Epsilon: 0.19
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1500, Total Steps: 18122, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.18
# Episode: 1600, Total Steps: 19600, Ep Step: 27, Raw Reward: 0.00, Epsilon: 0.16
# Episode: 1700, Total Steps: 20816, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.14
# Episode: 1800, Total Steps: 22324, Ep Step: 33, Raw Reward: 0.00, Epsilon: 0.13
# Episode: 1900, Total Steps: 24363, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.12
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2000, Total Steps: 25936, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.11
# Episode: 2100, Total Steps: 27346, Ep Step: 29, Raw Reward: 0.00, Epsilon: 0.10
# Episode: 2200, Total Steps: 28860, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.09
# Episode: 2300, Total Steps: 30270, Ep Step: 16, Raw Reward: 0.00, Epsilon: 0.08
# Episode: 2400, Total Steps: 31930, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.07
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2500, Total Steps: 33796, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.06
# Episode: 2600, Total Steps: 35332, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.06
# Episode: 2700, Total Steps: 37027, Ep Step: 35, Raw Reward: 0.00, Epsilon: 0.05
# Episode: 2800, Total Steps: 39338, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.05
# Episode: 2900, Total Steps: 41349, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.04
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3000, Total Steps: 43396, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.04
# Episode: 3100, Total Steps: 45121, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.04
# Episode: 3200, Total Steps: 46605, Ep Step: 27, Raw Reward: 0.00, Epsilon: 0.03
# Episode: 3300, Total Steps: 48107, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.03
# Episode: 3400, Total Steps: 49928, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.03
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3500, Total Steps: 51417, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.02
# Episode: 3600, Total Steps: 52777, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3700, Total Steps: 54008, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.02
# Episode: 3800, Total Steps: 55245, Ep Step: 24, Raw Reward: 0.00, Epsilon: 0.02
# Episode: 3900, Total Steps: 56716, Ep Step: 68, Raw Reward: 0.00, Epsilon: 0.02
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4000, Total Steps: 58562, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4100, Total Steps: 59784, Ep Step: 31, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4200, Total Steps: 61247, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4300, Total Steps: 62815, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4400, Total Steps: 64897, Ep Step: 23, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4500, Total Steps: 66766, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4600, Total Steps: 68491, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4700, Total Steps: 70478, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4800, Total Steps: 71568, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4900, Total Steps: 72835, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5000, Total Steps: 74255, Ep Step: 30, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5100, Total Steps: 76217, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5200, Total Steps: 78526, Ep Step: 50, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5300, Total Steps: 81706, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5400, Total Steps: 83533, Ep Step: 28, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5500, Total Steps: 85431, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5600, Total Steps: 87433, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5700, Total Steps: 89359, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5800, Total Steps: 90702, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5900, Total Steps: 92062, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6000, Total Steps: 93479, Ep Step: 29, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6100, Total Steps: 95662, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6200, Total Steps: 97622, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6300, Total Steps: 99908, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6400, Total Steps: 102724, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6500, Total Steps: 105272, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6600, Total Steps: 107563, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6700, Total Steps: 110161, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6800, Total Steps: 111644, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6900, Total Steps: 113195, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7000, Total Steps: 114671, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7100, Total Steps: 116624, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7200, Total Steps: 118783, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7300, Total Steps: 120889, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7400, Total Steps: 122403, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7500, Total Steps: 123818, Ep Step: 16, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7600, Total Steps: 125287, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7700, Total Steps: 126644, Ep Step: 16, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7800, Total Steps: 128529, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7900, Total Steps: 130976, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8000, Total Steps: 132946, Ep Step: 9, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8100, Total Steps: 134905, Ep Step: 15, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8200, Total Steps: 136715, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8300, Total Steps: 138352, Ep Step: 23, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8400, Total Steps: 140417, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8500, Total Steps: 141964, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8600, Total Steps: 144310, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8700, Total Steps: 146913, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8800, Total Steps: 149489, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8900, Total Steps: 151876, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9000, Total Steps: 154777, Ep Step: 22, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9100, Total Steps: 157507, Ep Step: 24, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9200, Total Steps: 158769, Ep Step: 23, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9300, Total Steps: 160944, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9400, Total Steps: 162507, Ep Step: 30, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9500, Total Steps: 164810, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9600, Total Steps: 166316, Ep Step: 10, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9700, Total Steps: 167311, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9800, Total Steps: 169082, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9900, Total Steps: 170562, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 10000, Total Steps: 171703, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.01
# Average reward of the last 100 episodes: 0.69
# Training with hyperparams: {'epsilon_max': 0.8}
# Episode: 100, Total Steps: 776, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.72
# Episode: 200, Total Steps: 1567, Ep Step: 2, Raw Reward: 0.00, Epsilon: 0.65
# Episode: 300, Total Steps: 2601, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.59
# Episode: 400, Total Steps: 3685, Ep Step: 16, Raw Reward: 0.00, Epsilon: 0.54
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 500, Total Steps: 4721, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.49
# Episode: 600, Total Steps: 5756, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.44
# Episode: 700, Total Steps: 6969, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.40
# Episode: 800, Total Steps: 8118, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.36
# Episode: 900, Total Steps: 9420, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.33
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1000, Total Steps: 10558, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.29
# Episode: 1100, Total Steps: 11749, Ep Step: 9, Raw Reward: 0.00, Epsilon: 0.27
# Episode: 1200, Total Steps: 13146, Ep Step: 2, Raw Reward: 0.00, Epsilon: 0.24
# Episode: 1300, Total Steps: 14619, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.22
# Episode: 1400, Total Steps: 15923, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.20
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1500, Total Steps: 17385, Ep Step: 15, Raw Reward: 0.00, Epsilon: 0.18
# Episode: 1600, Total Steps: 18730, Ep Step: 23, Raw Reward: 0.00, Epsilon: 0.16
# Episode: 1700, Total Steps: 20847, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.15
# Episode: 1800, Total Steps: 22659, Ep Step: 21, Raw Reward: 0.00, Epsilon: 0.13
# Episode: 1900, Total Steps: 24412, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.12
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2000, Total Steps: 26052, Ep Step: 26, Raw Reward: 0.00, Epsilon: 0.11
# Episode: 2100, Total Steps: 28055, Ep Step: 33, Raw Reward: 0.00, Epsilon: 0.10
# Episode: 2200, Total Steps: 30083, Ep Step: 27, Raw Reward: 1.00, Epsilon: 0.09
# Episode: 2300, Total Steps: 31550, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.08
# Episode: 2400, Total Steps: 32629, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.07
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2500, Total Steps: 33903, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.07
# Episode: 2600, Total Steps: 34974, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.06
# Episode: 2700, Total Steps: 36097, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.05
# Episode: 2800, Total Steps: 37089, Ep Step: 22, Raw Reward: 0.00, Epsilon: 0.05
# Episode: 2900, Total Steps: 38135, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.04
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3000, Total Steps: 39168, Ep Step: 25, Raw Reward: 0.00, Epsilon: 0.04
# Episode: 3100, Total Steps: 40121, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.04
# Episode: 3200, Total Steps: 41206, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.03
# Episode: 3300, Total Steps: 42165, Ep Step: 13, Raw Reward: 0.00, Epsilon: 0.03
# Episode: 3400, Total Steps: 43276, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.03
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3500, Total Steps: 44268, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3600, Total Steps: 45229, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3700, Total Steps: 46223, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3800, Total Steps: 47200, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3900, Total Steps: 48254, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.02
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4000, Total Steps: 49288, Ep Step: 30, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4100, Total Steps: 50307, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4200, Total Steps: 51343, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4300, Total Steps: 52322, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4400, Total Steps: 53392, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4500, Total Steps: 54493, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4600, Total Steps: 55502, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4700, Total Steps: 56524, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4800, Total Steps: 57558, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4900, Total Steps: 58638, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5000, Total Steps: 59690, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5100, Total Steps: 60674, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5200, Total Steps: 61903, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5300, Total Steps: 62960, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5400, Total Steps: 63875, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5500, Total Steps: 64840, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5600, Total Steps: 65794, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5700, Total Steps: 66789, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5800, Total Steps: 67807, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5900, Total Steps: 68763, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6000, Total Steps: 69799, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6100, Total Steps: 70762, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6200, Total Steps: 71665, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6300, Total Steps: 72584, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6400, Total Steps: 73583, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6500, Total Steps: 74590, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6600, Total Steps: 75713, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6700, Total Steps: 76678, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6800, Total Steps: 77558, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6900, Total Steps: 78453, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7000, Total Steps: 79316, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7100, Total Steps: 80229, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7200, Total Steps: 81026, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7300, Total Steps: 81849, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7400, Total Steps: 82661, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7500, Total Steps: 83410, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7600, Total Steps: 84197, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7700, Total Steps: 84990, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7800, Total Steps: 85775, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7900, Total Steps: 86533, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8000, Total Steps: 87313, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8100, Total Steps: 88090, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8200, Total Steps: 88835, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8300, Total Steps: 89614, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8400, Total Steps: 90386, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8500, Total Steps: 91191, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8600, Total Steps: 91973, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8700, Total Steps: 92725, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8800, Total Steps: 93562, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8900, Total Steps: 94332, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9000, Total Steps: 95175, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9100, Total Steps: 95945, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9200, Total Steps: 96725, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9300, Total Steps: 97473, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9400, Total Steps: 98290, Ep Step: 25, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9500, Total Steps: 99027, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9600, Total Steps: 99796, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9700, Total Steps: 100559, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9800, Total Steps: 101330, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9900, Total Steps: 102057, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 10000, Total Steps: 102926, Ep Step: 29, Raw Reward: 0.00, Epsilon: 0.01
# Average reward of the last 100 episodes: 0.77
# Training with hyperparams: {'epsilon_max': 0.81}
# Episode: 100, Total Steps: 860, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.73
# Episode: 200, Total Steps: 1825, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.66
# Episode: 300, Total Steps: 2872, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.60
# Episode: 400, Total Steps: 3898, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.54
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 500, Total Steps: 5130, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.49
# Episode: 600, Total Steps: 6215, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.44
# Episode: 700, Total Steps: 7250, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.40
# Episode: 800, Total Steps: 8102, Ep Step: 10, Raw Reward: 0.00, Epsilon: 0.36
# Episode: 900, Total Steps: 9238, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.33
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1000, Total Steps: 10509, Ep Step: 9, Raw Reward: 0.00, Epsilon: 0.30
# Episode: 1100, Total Steps: 11550, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.27
# Episode: 1200, Total Steps: 12786, Ep Step: 26, Raw Reward: 0.00, Epsilon: 0.24
# Episode: 1300, Total Steps: 14364, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.22
# Episode: 1400, Total Steps: 15555, Ep Step: 20, Raw Reward: 0.00, Epsilon: 0.20
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1500, Total Steps: 17212, Ep Step: 13, Raw Reward: 0.00, Epsilon: 0.18
# Episode: 1600, Total Steps: 19147, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.16
# Episode: 1700, Total Steps: 20677, Ep Step: 31, Raw Reward: 0.00, Epsilon: 0.15
# Episode: 1800, Total Steps: 22230, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.13
# Episode: 1900, Total Steps: 23888, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.12
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2000, Total Steps: 25452, Ep Step: 17, Raw Reward: 0.00, Epsilon: 0.11
# Episode: 2100, Total Steps: 26871, Ep Step: 25, Raw Reward: 0.00, Epsilon: 0.10
# Episode: 2200, Total Steps: 28864, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.09
# Episode: 2300, Total Steps: 30809, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.08
# Episode: 2400, Total Steps: 32195, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.07
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2500, Total Steps: 33849, Ep Step: 32, Raw Reward: 0.00, Epsilon: 0.07
# Episode: 2600, Total Steps: 35943, Ep Step: 49, Raw Reward: 0.00, Epsilon: 0.06
# Episode: 2700, Total Steps: 37954, Ep Step: 18, Raw Reward: 0.00, Epsilon: 0.05
# Episode: 2800, Total Steps: 40109, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.05
# Episode: 2900, Total Steps: 41536, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.04
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3000, Total Steps: 43003, Ep Step: 16, Raw Reward: 0.00, Epsilon: 0.04
# Episode: 3100, Total Steps: 44653, Ep Step: 43, Raw Reward: 1.00, Epsilon: 0.04
# Episode: 3200, Total Steps: 46755, Ep Step: 138, Raw Reward: 0.00, Epsilon: 0.03
# Episode: 3300, Total Steps: 48082, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.03
# Episode: 3400, Total Steps: 49998, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.03
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3500, Total Steps: 53280, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.02
# Episode: 3600, Total Steps: 55293, Ep Step: 19, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3700, Total Steps: 57518, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3800, Total Steps: 60082, Ep Step: 9, Raw Reward: 0.00, Epsilon: 0.02
# Episode: 3900, Total Steps: 62046, Ep Step: 50, Raw Reward: 0.00, Epsilon: 0.02
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4000, Total Steps: 64543, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4100, Total Steps: 67202, Ep Step: 24, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4200, Total Steps: 69122, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4300, Total Steps: 71519, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4400, Total Steps: 72988, Ep Step: 22, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4500, Total Steps: 75176, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4600, Total Steps: 77170, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4700, Total Steps: 78265, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4800, Total Steps: 79161, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4900, Total Steps: 80224, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5000, Total Steps: 83040, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5100, Total Steps: 84994, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5200, Total Steps: 87447, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5300, Total Steps: 90195, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5400, Total Steps: 91326, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5500, Total Steps: 92421, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5600, Total Steps: 94619, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5700, Total Steps: 97516, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5800, Total Steps: 98500, Ep Step: 15, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5900, Total Steps: 99634, Ep Step: 18, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6000, Total Steps: 101751, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6100, Total Steps: 104385, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6200, Total Steps: 105756, Ep Step: 18, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6300, Total Steps: 108304, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6400, Total Steps: 111394, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6500, Total Steps: 114187, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6600, Total Steps: 115565, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6700, Total Steps: 117379, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6800, Total Steps: 119556, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6900, Total Steps: 121800, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7000, Total Steps: 122713, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7100, Total Steps: 123676, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7200, Total Steps: 125341, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7300, Total Steps: 128335, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7400, Total Steps: 130362, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7500, Total Steps: 131651, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7600, Total Steps: 133544, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7700, Total Steps: 135944, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7800, Total Steps: 138329, Ep Step: 23, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7900, Total Steps: 139377, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8000, Total Steps: 140686, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8100, Total Steps: 142922, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8200, Total Steps: 145312, Ep Step: 22, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8300, Total Steps: 148523, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8400, Total Steps: 150566, Ep Step: 9, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8500, Total Steps: 152815, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8600, Total Steps: 154808, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8700, Total Steps: 157958, Ep Step: 25, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8800, Total Steps: 159947, Ep Step: 76, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8900, Total Steps: 162991, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9000, Total Steps: 164951, Ep Step: 18, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9100, Total Steps: 167345, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9200, Total Steps: 169425, Ep Step: 23, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9300, Total Steps: 170859, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9400, Total Steps: 172194, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9500, Total Steps: 175183, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9600, Total Steps: 177769, Ep Step: 29, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9700, Total Steps: 179882, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9800, Total Steps: 182700, Ep Step: 29, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9900, Total Steps: 185103, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 10000, Total Steps: 187995, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Average reward of the last 100 episodes: 0.66
# Best hyperparams: {'epsilon_max': 0.8} with average reward: 0.77 and reward variance: 0.18
