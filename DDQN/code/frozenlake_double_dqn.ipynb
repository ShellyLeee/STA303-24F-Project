# %% [markdown]
# # Double DQN algorithm implementation
# This notebook contains five parts:
# - Environment Construction
# - Run the model with defailt parameters
# - Hyperparameters tuning
# - Repetition of the best performance of Double DQN
# - Random parameter adjustment

# %% [markdown]
# ## 1. Environment Construction

# %%
# Import necessary modules
import os
import gc
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt
import gymnasium as gym
from agent.base_agent import BaseAgent
from utils import seed_everything

# %%
# Set device to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Environment setup
gc.collect()
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'  # Set CUDA launch blocking to 1 for debugging CUDA-related errors


# Replay Buffer Class

class ReplayBuffer:
    def __init__(self, capacity):
        """
        Experience replay buffer used to store transitions
        """
        self.capacity = capacity
        # 缓冲区达到最大容量时，新元素将会替代旧元素
        self.buffer = deque(maxlen=capacity)

    def store(self, state, action, next_state, reward, done):
        """
        Store a transition in the buffer
        """
        self.buffer.append((state, action, next_state, reward, done))

    def sample(self, batch_size):
        """
        Randomly sample a batch of transitions from the buffer
        
        """
        indices = np.random.choice(len(self.buffer), size=batch_size, replace=False)
      
        states, actions, next_states, rewards, dones = zip(*(self.buffer[idx] for idx in indices))

        # Convert sampled transitions to tensors
        states = torch.stack(states).to(device)
        actions = torch.tensor(actions, dtype=torch.long, device=device)
        next_states = torch.stack(next_states).to(device)
        rewards = torch.tensor(rewards, dtype=torch.float32, device=device)
        dones = torch.tensor(dones, dtype=torch.bool, device=device)

        return states, actions, next_states, rewards, dones
    # 属性访问器
    def __len__(self):
        return len(self.buffer)

class Qnet(nn.Module):
    def __init__(self, num_actions, input_dim):
        """
        Neural network for Deep Q-Learning
        """
        
        super(Qnet, self).__init__()
        self.fc_layers = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(64, 32),
            nn.ReLU(inplace=True),
            nn.Linear(32, num_actions)
        )
        self._initialize_weights()

    def forward(self, x):
        """
        Forward pass through the network
        """
        return self.fc_layers(x)


    def _initialize_weights(self):
        """
        Initialize weights for linear layers using Kaiming uniform initialization
        """
        for layer in self.fc_layers:
            # 对于每一层检查是否是线性层
            if isinstance(layer, nn.Linear):
                nn.init.kaiming_uniform_(layer.weight, nonlinearity='relu')

# %%
# DQN Agent Class inheriting from Agent
class DQNAgent(BaseAgent):
    def __init__(self, env, hyperparams):
        """
        DQN Agent class for interacting with the environment and learning
        """
        super(DQNAgent, self).__init__(env, hyperparams)
        self.replay_memory = ReplayBuffer(hyperparams['memory_capacity'])

        # Main and target networks
       
        self.model = Qnet(self.num_actions, self.state_dim).to(device)
        self.target_network = Qnet(self.num_actions, self.state_dim).to(device)
       
        self.update_target_network()

        # Optimizer and loss function
        self.optimizer = optim.Adam(self.model.parameters(), lr=hyperparams['learning_rate'])
        self.criterion = nn.MSELoss()
        
        # Additional hyperparameters
        self.discount = hyperparams['discount_factor']
        self.epsilon = hyperparams['epsilon_max']
        self.epsilon_min = hyperparams['epsilon_min']
        self.epsilon_decay = hyperparams['epsilon_decay']
        self.epsilon_history = []
        self.clip_grad_norm = hyperparams['clip_grad_norm']
        self.loss_history = []
        self.running_loss = 0
        self.learned_counts = 0

    def select_action(self, state):
        """
        Select an action using epsilon-greedy policy
        """
        if np.random.random() < self.epsilon:
            return self.env.action_space.sample()
        with torch.no_grad():
            Q_values = self.model(state)
            return torch.argmax(Q_values).item()

    def learn(self, batch_size, done):
        """
        Learn from a batch of experiences using the DQN update rule
        """
        # Sample a batch from the replay buffer
        states, actions, next_states, rewards, dones = self.replay_memory.sample(batch_size)
        actions = actions.unsqueeze(1)
        rewards = rewards.unsqueeze(1)
        dones = dones.unsqueeze(1)
        # Compute predicted Q-values and target Q-values
        predicted_q = self.model(states).gather(dim=1, index=actions)
        with torch.no_grad():
            # use main network to select best action
            best_actions = self.model(next_states).argmax(dim=1, keepdim=True)
            # use target nerwork to evaluate the best action
            next_target_q_value = self.target_network(next_states).gather(1,best_actions)
            next_target_q_value[dones] = 0
            # compute target q value
            y_js = rewards + (self.discount * next_target_q_value)
        # Compute loss
        loss = self.criterion(predicted_q, y_js)
        self.running_loss += loss.item()
        self.learned_counts += 1
        if done:
            self.loss_history.append(self.running_loss / self.learned_counts)
            self.running_loss, self.learned_counts = 0, 0
        # Backpropagate the loss
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.clip_grad_norm)
        self.optimizer.step()

    def update_target_network(self):
        """
        Update the target network by copying weights from the main network
        """
        self.target_network.load_state_dict(self.model.state_dict())

    def update_epsilon(self):
        """
        Update epsilon value for epsilon-greedy policy
        """
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
        self.epsilon_history.append(self.epsilon)
    def save(self, path):
        """
        Save the trained model
        """
        torch.save(self.model.state_dict(), path)
    
    def load(self, path):
        """
        Load the trained model
        """
        self.model.load_state_dict(torch.load(path, map_location=device))

# %%
# Trainer Class
class Trainer:
    def __init__(self, env, agent, hyperparams):
        """
        Trainer class to manage training and evaluation of the agent
        """
        self.env = env
        self.agent = agent
        self.hyperparams = hyperparams
        self.reward_history = []
        self.step_history = []
        if hasattr(agent, 'replay_memory'):
            self.use_replay_memory = True
        else:
            self.use_replay_memory = False

    def state_preprocess(self, state):
        """
        Convert the state to one-hot representation 
        """
        onehot_vector = torch.zeros(self.env.observation_space.n, dtype=torch.float32, device=device)
        onehot_vector[state] = 1
        return onehot_vector
    def train(self):
        """
        Train the agent for a specified number of episodes
        """
        total_steps = 0
        for episode in range(1, self.hyperparams['max_episodes'] + 1):
            state, _ = self.env.reset(seed=seed)
            state = self.state_preprocess(state)
            done, truncation = False, False
            step_size, episode_reward = 0, 0

            while not done and not truncation:
                # Select and execute an action
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)
                next_state = self.state_preprocess(next_state)

                # use ReplayBuffer
                if self.use_replay_memory:
                    self.agent.replay_memory.store(state, action, next_state, reward, done)
                    if len(self.agent.replay_memory) > self.hyperparams['batch_size'] and sum(self.reward_history) > 0:
                        self.agent.learn(self.hyperparams['batch_size'], (done or truncation))
                        # Update target network periodically
                        if total_steps % self.hyperparams['update_frequency'] == 0:
                            self.agent.update_target_network()

                state = next_state
                episode_reward += reward
                step_size += 1

            self.reward_history.append(episode_reward)
            self.step_history.append(step_size)  # Track steps for each episode
            total_steps += step_size
            self.agent.update_epsilon()

            # Save the model at specified intervals
            if episode % self.hyperparams['save_interval'] == 0:
                os.makedirs(self.hyperparams['model_dir'], exist_ok=True)
                self.agent.save(os.path.join(self.hyperparams['model_dir'], f'{episode}.pth'))
                print('\n~~~~~~Interval Save: Model saved.\n')
            # Print episode information at specified intervals
            if episode % self.hyperparams['print_interval'] == 0:
                print(f"Episode: {episode}, Total Steps: {total_steps}, Ep Step: {step_size}, Raw Reward: {episode_reward:.2f}, Epsilon: {self.agent.epsilon:.2f}")
        self.plot_training(episode)

    def test(self, max_episodes=None):
        """
        Test the trained agent
        """
        # Load the trained model
        self.agent.load(os.path.join(self.hyperparams['model_dir'], f"{self.hyperparams['train_episodes']}.pth"))
        self.agent.model.eval()

        if max_episodes is None:
            max_episodes = self.hyperparams['max_episodes']

        for episode in range(1, max_episodes + 1):
            state, _ = self.env.reset(seed=seed)
            done, truncation = False, False
            step_size, episode_reward = 0, 0

            while not done and not truncation:
                # Select an action
                state = self.state_preprocess(state)
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)
                state = next_state
                episode_reward += reward
                step_size += 1

            # Print episode information
            print(f"Episode: {episode}, Steps: {step_size}, Reward: {episode_reward:.2f}")


    def plot_training(self, episode):
        """
        Plot the training reward history, loss history, and step convergence
        """
        # Plot Rewards
        sma = np.convolve(self.reward_history, np.ones(50)/50, mode='valid')
        plt.figure()
        plt.title("Rewards")
        plt.plot(self.reward_history, label='Raw Reward', color='#F6CE3B', alpha=1)
        plt.plot(sma, label='SMA 50', color='#385DAA')
        plt.xlabel("Episode")
        plt.ylabel("Rewards")
        plt.legend()
        if episode == self.hyperparams['max_episodes']:
            os.makedirs(self.hyperparams['plot_dir'], exist_ok=True)
            plt.savefig(os.path.join(self.hyperparams['plot_dir'], 'reward_plot.png'), format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()

        # Plot Loss
        plt.figure()
        plt.title("Loss")
        plt.plot(self.agent.loss_history, label='Loss', color='#CB291A', alpha=1)
        plt.xlabel("Episode")
        plt.ylabel("Loss")
        if episode == self.hyperparams['max_episodes']:
            plt.savefig(os.path.join(self.hyperparams['plot_dir'], 'loss_plot.png'), format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()
        # Plot Epsilon
        plt.figure()
        plt.title("Epsilon", fontweight='bold')
        plt.plot(self.agent.epsilon_history, label='Epsilon', color='#FF5733', alpha=1)
        plt.xlabel("Episode")
        plt.ylabel("Epsilon")
        plt.legend()
        if episode == self.hyperparams['max_episodes']:
            plt.savefig(os.path.join(self.hyperparams['plot_dir'], 'epsilon_plot.png'), format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()

# %%
# Main Function to Set Up and Train/Test the Model
if __name__ == "__main__":
    method_name = "double_dqn" 
    train_mode = True
    train_episodes = 10000
    render = not train_mode
    map_size = 4  
    seed = 1

    # Build config
    config = {
         "train_mode": train_mode,
        "method_name": method_name,
        "model_dir": f'output/{method_name}/model/{map_size}x{map_size}/',
        "plot_dir": f'output/{method_name}/plt/{map_size}x{map_size}/',
        "save_interval": 500,
        "print_interval": 100,
        "clip_grad_norm": 3,
        "learning_rate": 6e-4,
        "discount_factor": 0.93,
        "batch_size": 32,
        "update_frequency": 10,
        "max_episodes": train_episodes if train_mode else 10,
        "train_episodes": train_episodes,
        "max_steps": 200,
        "render": render,
        "epsilon_max": 0.999 if train_mode else -1,
        "epsilon_min": 0.01,
        "epsilon_decay": 0.999,
        "memory_capacity": 4000 if train_mode else 0,
        "map_size": map_size,
        "render_fps": 6,
    }

    # Seed everything for reproducibility
    seed_everything(seed)

    # Create environment
    env = gym.make(
        'FrozenLake-v1', 
        map_name=f"{config['map_size']}x{config['map_size']}", 
        is_slippery=True, 
        max_episode_steps=config['max_steps'],
        render_mode="human" if config['render'] else None
    )
    env.reset(seed=seed)
    env.action_space.seed(seed)
    env.metadata['render_fps'] = config['render_fps']
    # Create agent and trainer
    agent = DQNAgent(env, config)
    trainer = Trainer(env, agent, config)

# %% [markdown]
# ## 2. Run the model with defailt parameters

# %%
import torch
device = torch.device ('cpu')
# Main Function to Set Up and Train/Test the Model
if __name__ == "__main__":
    method_name = "double_dqn" 
    train_mode = True
    train_episodes = 10000
    render = not train_mode
    map_size = 4  
    seed = 1

    # Build config
    config = {
         "train_mode": train_mode,
        "method_name": method_name,
        "model_dir": f'output/{method_name}/model/{map_size}x{map_size}/',
        "plot_dir": f'output/{method_name}/plt/{map_size}x{map_size}/',
        "save_interval": 500,
        "print_interval": 100,
        "clip_grad_norm": 3,
        "learning_rate": 6e-4,
        "discount_factor": 0.93,
        "batch_size": 32,
        "update_frequency": 10,
        "max_episodes": train_episodes if train_mode else 10,
        "train_episodes": train_episodes,
        "max_steps": 200,
        "render": render,
        "epsilon_max": 0.999 if train_mode else -1,
        "epsilon_min": 0.01,
        "epsilon_decay": 0.999,
        "memory_capacity": 4000 if train_mode else 0,
        "map_size": map_size,
        "render_fps": 6,
    }

    # Seed everything for reproducibility
    seed_everything(seed)

    # Create environment
    env = gym.make(
        'FrozenLake-v1', 
        map_name=f"{config['map_size']}x{config['map_size']}", 
        is_slippery=True, 
        max_episode_steps=config['max_steps'],
        render_mode="human" if config['render'] else None
    )
    env.reset(seed=seed)
    env.action_space.seed(seed)
    env.metadata['render_fps'] = config['render_fps']
    # Create agent and trainer
    agent = DQNAgent(env, config)
    trainer = Trainer(env, agent, config)
    # Train or test
    if config['train_mode']:
        trainer.train()
    else:
        trainer.test()
# Out:
# Episode: 100, Total Steps: 718, Ep Step: 2, Raw Reward: 0.00, Epsilon: 0.90
# Episode: 200, Total Steps: 1540, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.82
# Episode: 300, Total Steps: 2399, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.74
# Episode: 400, Total Steps: 3223, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.67
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 500, Total Steps: 4150, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.61
# Episode: 600, Total Steps: 4869, Ep Step: 10, Raw Reward: 0.00, Epsilon: 0.55
# Episode: 700, Total Steps: 5641, Ep Step: 15, Raw Reward: 0.00, Epsilon: 0.50
# Episode: 800, Total Steps: 6467, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0
Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5200, Total Steps: 74592, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5300, Total Steps: 75302, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5400, Total Steps: 76299, Ep Step: 18, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5500, Total Steps: 77214, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5600, Total Steps: 77965, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5700, Total Steps: 81114, Ep Step: 20, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5800, Total Steps: 84837, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5900, Total Steps: 88176, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6000, Total Steps: 91841, Ep Step: 200, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6100, Total Steps: 94071, Ep Step: 10, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6200, Total Steps: 95247, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6300, Total Steps: 96010, Ep Step: 26, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6400, Total Steps: 97233, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6500, Total Steps: 98274, Ep Step: 33, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6600, Total Steps: 101011, Ep Step: 39, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6700, Total Steps: 104748, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6800, Total Steps: 107450, Ep Step: 37, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6900, Total Steps: 111160, Ep Step: 2, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7000, Total Steps: 113226, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7100, Total Steps: 114035, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7200, Total Steps: 115000, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7300, Total Steps: 115920, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7400, Total Steps: 116863, Ep Step: 16, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7500, Total Steps: 117891, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7600, Total Steps: 118860, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7700, Total Steps: 119813, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7800, Total Steps: 120745, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7900, Total Steps: 121675, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8000, Total Steps: 122580, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8100, Total Steps: 123657, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8200, Total Steps: 124557, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8300, Total Steps: 125437, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8400, Total Steps: 126368, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8500, Total Steps: 127253, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8600, Total Steps: 128149, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8700, Total Steps: 129066, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8800, Total Steps: 130021, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8900, Total Steps: 130970, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9000, Total Steps: 131894, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9100, Total Steps: 132803, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9200, Total Steps: 133730, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9300, Total Steps: 134616, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9400, Total Steps: 135549, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9500, Total Steps: 136504, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9600, Total Steps: 137431, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9700, Total Steps: 138368, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9800, Total Steps: 139327, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9900, Total Steps: 140238, Ep Step: 18, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 10000, Total Steps: 141175, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.01

# %% [markdown]
# ## 3. Hyperparameter tuning
# In this part, we combine adjustment parameters to find the optimal DDQN parameter combination.
#
# The optimal parameter policy is shown at the bottom of the output.

# %%
import numpy as np
import itertools
import torch
device = torch.device("cpu")


param_names = ["epsilon_max","learning_rate","discount_factor"]
param_values = [[0.8,0.99],[0.0003,0.001,0.01],[0.9,0.95,0.97]]
param_combinations = list(itertools.product(*param_values))

results = []
 

for params in param_combinations:
   
    hyperparams = dict(zip(param_names,params))
    print(F"Traning with hyperparams: {hyperparams}")
    
    config.update(hyperparams)
  
    # Seed everything for reproducibility
    seed_everything(seed)

    # Create environment
    env = gym.make(
        'FrozenLake-v1', 
        map_name=f"{config['map_size']}x{config['map_size']}", 
        is_slippery=True, 
        max_episode_steps=config['max_steps'],
        render_mode="human" if config['render'] else None
    )
    env.reset(seed=seed)
    env.action_space.seed(seed)
    env.metadata['render_fps'] = config['render_fps']
    
    trainer.train()
    avg_reward = np.mean(trainer.reward_history[-100:])  
    results.append((hyperparams, avg_reward))


best_params = max(results, key=lambda x: x[1])
print(f"Best hyperparams: {best_params[0]} with average reward: {best_params[1]:.2f}")
# Out:
# Traning with hyperparams: {'epsilon_max': 0.8, 'learning_rate': 0.0003, 'discount_factor': 0.9}
# Episode: 100, Total Steps: 764, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.90
# Episode: 200, Total Steps: 1586, Ep Step: 10, Raw Reward: 0.00, Epsilon: 0.82
# Episode: 300, Total Steps: 2435, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.74
# Episode: 400, Total Steps: 3285, Ep Step: 17, Raw Reward: 0.00, Epsilon: 0.67
#
# ~~~~~~Interval Save: Model saved.
#
# Episode:
Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 3900, Total Steps: 28247, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4000, Total Steps: 28944, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4100, Total Steps: 29654, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4200, Total Steps: 30366, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4300, Total Steps: 31068, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4400, Total Steps: 31776, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4500, Total Steps: 32509, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4600, Total Steps: 33237, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4700, Total Steps: 33968, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4800, Total Steps: 34689, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4900, Total Steps: 35437, Ep Step: 9, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5000, Total Steps: 36164, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5100, Total Steps: 36931, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5200, Total Steps: 37639, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5300, Total Steps: 38353, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5400, Total Steps: 39081, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5500, Total Steps: 39824, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5600, Total Steps: 40564, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5700, Total Steps: 41286, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5800, Total Steps: 42145, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5900, Total Steps: 43014, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6000, Total Steps: 43842, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6100, Total Steps: 44628, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6200, Total Steps: 45377, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6300, Total Steps: 46087, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6400, Total Steps: 46816, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6500, Total Steps: 47541, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6600, Total Steps: 48240, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6700, Total Steps: 48961, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6800, Total Steps: 49656, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6900, Total Steps: 50381, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7000, Total Steps: 51106, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7100, Total Steps: 51868, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7200, Total Steps: 52569, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7300, Total Steps: 53291, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7400, Total Steps: 54005, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7500, Total Steps: 54738, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7600, Total Steps: 55472, Ep Step: 9, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7700, Total Steps: 56208, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7800, Total Steps: 56968, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7900, Total Steps: 57721, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8000, Total Steps: 58435, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8100, Total Steps: 59167, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8200, Total Steps: 59875, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8300, Total Steps: 60590, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8400, Total Steps: 61340, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8500, Total Steps: 62044, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8600, Total Steps: 62760, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8700, Total Steps: 63509, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8800, Total Steps: 64234, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8900, Total Steps: 64933, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9000, Total Steps: 65701, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9100, Total Steps: 66425, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9200, Total Steps: 67159, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9300, Total Steps: 67884, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9400, Total Steps: 68608, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9500, Total Steps: 69312, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9600, Total Steps: 70039, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9700, Total Steps: 70790, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9800, Total Steps: 71505, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9900, Total Steps: 72216, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 10000, Total Steps: 72927, Ep Step: 7, Raw Reward: 1.00, Epsilon: 0.01
# Best hyperparams: {'epsilon_max': 0.8, 'learning_rate': 0.0003, 'discount_factor': 0.9} with average reward: 0.96

# %% [markdown]
# ## 4. Repetition of the Best Performance of Double DQN

# %%
import numpy as np
import itertools
import torch
device = torch.device("cpu")

param_names = ["epsilon_max","learning_rate","discount_factor"]
param_values = [0.8,0.0003,0.9]
results = []
 

hyperparams = dict(zip(param_names,param_values))
print(F"Traning with hyperparams: {hyperparams}")

config.update(hyperparams)
# set seed

env = gym.make(
    'FrozenLake-v1',
    map_name = f"{config['map_size']}x{config['map_size']}",
    is_slippery = True,
    max_episode_steps = config['max_steps']
)
env.reset(seed=config.get('seed', 0))
env.action_space.seed(config.get('seed', 0))


agent = DQNAgent(env, config)
trainer = Trainer(env, agent, config)

trainer.train()
avg_reward = np.mean(trainer.reward_history[-100:])  
results.append((hyperparams, avg_reward))


best_params = max(results, key=lambda x: x[1])
print(f"Best hyperparams: {best_params[0]} with average reward: {best_params[1]:.2f}")
# Out:
# Traning with hyperparams: {'epsilon_max': 0.8, 'learning_rate': 0.0003, 'discount_factor': 0.9}
# Episode: 100, Total Steps: 777, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.72
# Episode: 200, Total Steps: 1586, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.65
# Episode: 300, Total Steps: 2343, Ep Step: 15, Raw Reward: 0.00, Epsilon: 0.59
# Episode: 400, Total Steps: 3185, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0
Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5500, Total Steps: 45509, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5600, Total Steps: 46339, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5700, Total Steps: 47138, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 5800, Total Steps: 47959, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5900, Total Steps: 48781, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6000, Total Steps: 49647, Ep Step: 30, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 6100, Total Steps: 50473, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6200, Total Steps: 51247, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6300, Total Steps: 52086, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6400, Total Steps: 52978, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6500, Total Steps: 53802, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6600, Total Steps: 54634, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6700, Total Steps: 55445, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6800, Total Steps: 56236, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6900, Total Steps: 57061, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7000, Total Steps: 57864, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7100, Total Steps: 58612, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7200, Total Steps: 59454, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7300, Total Steps: 60312, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7400, Total Steps: 61141, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7500, Total Steps: 61949, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7600, Total Steps: 62731, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7700, Total Steps: 63541, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7800, Total Steps: 64335, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7900, Total Steps: 65143, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8000, Total Steps: 65971, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8100, Total Steps: 66790, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8200, Total Steps: 67599, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8300, Total Steps: 68395, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8400, Total Steps: 69199, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8500, Total Steps: 70050, Ep Step: 25, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8600, Total Steps: 70848, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8700, Total Steps: 71652, Ep Step: 19, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 8800, Total Steps: 72449, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8900, Total Steps: 73244, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9000, Total Steps: 74057, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9100, Total Steps: 74893, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9200, Total Steps: 75716, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9300, Total Steps: 76514, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9400, Total Steps: 77345, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9500, Total Steps: 78136, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9600, Total Steps: 78929, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 9700, Total Steps: 79707, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9800, Total Steps: 80493, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9900, Total Steps: 81290, Ep Step: 8, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 10000, Total Steps: 82103, Ep Step: 19, Raw Reward: 0.00, Epsilon: 0.01
# Best hyperparams: {'epsilon_max': 0.8, 'learning_rate': 0.0003, 'discount_factor': 0.9} with average reward: 0.88

# %% [markdown]
# ## 5. Random parameter adjustment
# Since the combination parameter tuning needs a lot of time, the method of random parameter tuning is chosen to select whether the parameters with better performance.

# %%
import numpy as np
import itertools
import random
import torch
device = torch.device("cpu")



param_names = ["train_episodes","learning_rate","discount_factor", "update_frequency"]
param_values = [random.choice([10000,5000,15000]),random.choice([0.0003,0.001,0.01]),random.choice([0.9,0.95,0.97]),random.choice([10,15,20])]
results = []

hyperparams = dict(zip(param_names, param_values))
print(f"Training with hyperparams: {hyperparams}")
if __name__ == "__main__":
    method_name = "double_dqn"  
    train_mode = True
    train_episodes = 10000
    render = not train_mode
    map_size = 4  # Start with 4x4 map
    seed = 1

    # Build config
    config = {
         "train_mode": train_mode,
        "method_name": method_name,
        "model_dir": f'output/{method_name}/model/{map_size}x{map_size}/',
        "plot_dir": f'output/{method_name}/plt/{map_size}x{map_size}/',
        "save_interval": 500,
        "print_interval": 100,
        "clip_grad_norm": 3,
        "learning_rate": 6e-4,
        "discount_factor": 0.93,
        "batch_size": 32,
        "update_frequency": 10,
        "max_episodes": train_episodes if train_mode else 10,
        "train_episodes": train_episodes,
        "max_steps": 200,
        "render": render,
        "epsilon_max": 0.999 if train_mode else -1,
        "epsilon_min": 0.01,
        "epsilon_decay": 0.999,
        "memory_capacity": 4000 if train_mode else 0,
        "map_size": map_size,
        "render_fps": 6,
    }

    config.update(hyperparams)

        # set seed
    seed_everything(seed)

    # Create environment
    env = gym.make(
        'FrozenLake-v1', 
        map_name=f"{config['map_size']}x{config['map_size']}", 
        is_slippery=True, 
        max_episode_steps=config['max_steps'], 
        render_mode="human" if config['render'] else None)

    env.reset(seed=seed)
    env.action_space.seed(seed)
    env.metadata['render_fps'] = config['render_fps']
  
    agent = DQNAgent(env, config)
    trainer = Trainer(env, agent, config)

 
    trainer.train()

  
    avg_reward = np.mean(trainer.reward_history[-100:])

  
    reward_variance = np.var(trainer.reward_history[-100:])

 
    results.append((hyperparams, avg_reward, reward_variance))
    results.append((hyperparams, avg_reward))


best_params = max(results, key=lambda x: x[1])
best_avg_reward, best_variance = best_params[1], best_params[2]
print(f"Best hyperparams: {best_params[0]} with average reward: {best_avg_reward:.2f} and reward variance: {best_variance:.2f}")
# Out:
# Training with hyperparams: {'train_episodes': 10000, 'learning_rate': 0.01, 'discount_factor': 0.9, 'update_frequency': 15}
# Episode: 100, Total Steps: 670, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.90
# Episode: 200, Total Steps: 1444, Ep Step: 13, Raw Reward: 0.00, Epsilon: 0.82
# Episode: 300, Total Steps: 2133, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.74
# Episode: 400, Total Steps: 2873, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.67
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 500, Total Steps: 3601, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.61
# Episode: 600, Total Steps: 4364, Ep Step: 2, Raw Reward: 0.00, Epsilon: 0.55
# Episode: 700, Total Steps: 5059, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.50
# Episode: 800, Total Steps: 5860, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.45
# Episode: 900, Total Steps: 6709, Ep Step: 10, Raw Reward: 0.00, Epsilon: 0.41
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1000, Total Steps: 7570, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.37
# Episode: 1100, Total Steps: 8439, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.33
# Episode: 1200, Total Steps: 9361, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.30
# Episode: 1300, Total Steps: 10264, Ep Step: 13, Raw Reward: 0.00, Epsilon: 0.27
# Episode: 1400, Total Steps: 11147, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.25
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1500, Total Steps: 12000, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.22
# Episode: 1600, Total Steps: 12911, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.20
# Episode: 1700, Total Steps: 13758, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.18
# Episode: 1800, Total Steps: 14717, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.16
# Episode: 1900, Total Steps: 15710, Ep Step: 2, Raw Reward: 0.00, Epsilon: 0.15
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2000, Total Steps: 16762, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.14
# Episode: 2100, Total Steps: 17783, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.12
# Episode: 2200, Total Steps: 18601, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.11
# Episode: 2300, Total Steps: 19418, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.10
# Episode: 2400, Total Steps: 20279, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.09
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2500, Total Steps: 21135, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.08
# Episode: 2600, Total Steps: 21971, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.07
# Episode: 2700, Total Steps: 22964, Ep Step: 13, Raw Reward: 0.00, Epsilon: 0.07
# Episode: 2800, Total Steps: 24060, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.06
# Episode: 2900, Total Steps: 25177, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.05
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3000, Total Steps: 26107, Ep Step: 9, Raw Reward: 0.00, Epsilon: 0.05
# Episode: 3100, Total Steps: 27202, Ep Step: 15, Raw Reward: 0.00, Epsilon: 0.04
# Episode: 3200, Total Steps: 28062, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.04
# Episode: 3300, Total Steps: 29232, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0