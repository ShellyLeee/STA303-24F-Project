# %% [markdown]
# # Dueling DQN Algorithm implementation
# This is the algorithm with the BEST PERFORMANCE under our matric!
#
# This notebook contains two parts:
# - Implement Dueling DQN algorithm with default parameters
# - Repetition of the best performance of Deuling DQN with the best parameters combination

# %% [markdown]
# ## 1. Implement Dueling DQN algorithm with default parameters

# %%
# !pip install -r requirements.txt
# Out:
# Collecting tqdm==4.66.5 (from -r requirements.txt (line 1))
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting matplotlib==3.7.5 (from -r requirements.txt (line 2))
#   Using cached matplotlib-3.7.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.7 kB)
# Collecting pandas==1.5.3 (from -r requirements.txt (line 3))
#   Using cached pandas-1.5.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting gymnasium==0.29.1 (from -r requirements.txt (line 4))
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting numpy==1.22.0 (from -r requirements.txt (line 5))
#   Using cached numpy-1.22.0-cp311-cp311-macosx_12_0_arm64.whl
# Collecting pygame==2.5.2 (from -r requirements.txt (line 6))
#   Using cached pygame-2.5.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from matplotlib==3.7.5->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/shellyli/anaconda3/lib/python3.11/site-packages (from pandas==1.5.3->-r requirements.txt (line 3)) (2024.1)
# INFO: pip is looking at multiple versions of pandas to determine which version is compatible with other requirements. This could take a while.
# ERROR: Cannot install -r requirements.txt (line 2), -r requirements.txt (line 3) and numpy==1.22.0 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested numpy==1.22.0
#     matplotlib 3.7.5 depends on numpy<2 and >=1.20
#     pandas 1.5.3 depends on numpy>=1.21.0; python_version >= "3.10"
#     pandas 1.5.3 depends on numpy>=1.23.2; python_version >= "3.11"
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts

# %%
# Import necessary modules
import os
import gc
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt
import gymnasium as gym
from agent.base_agent import BaseAgent
from utils import seed_everything

# Set device to GPU if available
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = "cpu"
# Environment setup
gc.collect()
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'  # Set CUDA launch blocking to 1 for debugging CUDA-related errors

# %%
# Replay Buffer Class
class ReplayBuffer:
    def __init__(self, capacity):
        """
        Experience replay buffer used to store transitions
        """
        self.capacity = capacity
        self.buffer = deque(maxlen=capacity)

    def store(self, state, action, next_state, reward, done):
        """
        Store a transition in the buffer
        """
        self.buffer.append((state, action, next_state, reward, done))

    def sample(self, batch_size):
        """
        Randomly sample a batch of transitions from the buffer
        """
        indices = np.random.choice(len(self.buffer), size=batch_size, replace=False)
        states, actions, next_states, rewards, dones = zip(*(self.buffer[idx] for idx in indices))

        # Convert sampled transitions to tensors
        states = torch.stack(states).to(device)
        actions = torch.tensor(actions, dtype=torch.long, device=device)
        next_states = torch.stack(next_states).to(device)
        rewards = torch.tensor(rewards, dtype=torch.float32, device=device)
        dones = torch.tensor(dones, dtype=torch.bool, device=device)

        return states, actions, next_states, rewards, dones

    def __len__(self):
        return len(self.buffer)

# %%
# define two-stream Q-net class
class Qnet(nn.Module):
    def __init__(self, num_actions, input_dim):
        """
        Neural network for Deep Q-Learning
        """
        super(Qnet, self).__init__()
        self.fc_layers = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(64, 32),
            nn.ReLU(inplace=True),
        )
        # Value stream
        self.value = nn.Linear(32, 1)
        # Advantage stream
        self.advantage = nn.Linear(32, num_actions)

    def forward(self, x):
        x = self.fc_layers(x)
        value = self.value(x)
        advantage = self.advantage(x)
        # Compute Q-values: Q(s, a) = V(s) + A(s, a) - mean(A(s, a))
        q_values = value + advantage - advantage.mean()
        return q_values

    def _initialize_weights(self):
        """
        Initialize weights for linear layers using Kaiming uniform initialization
        """
        for layer in self.fc_layers:
            if isinstance(layer, nn.Linear):
                nn.init.kaiming_uniform_(layer.weight, nonlinearity='relu')

# %%
# DQN Agent Class inheriting from Agent
class DQNAgent(BaseAgent):
    def __init__(self, env, hyperparams):
        """
        DQN Agent class for interacting with the environment and learning
        """
        super(DQNAgent, self).__init__(env, hyperparams)
        self.replay_memory = ReplayBuffer(hyperparams['memory_capacity'])

        # Main and target networks
        self.model = Qnet(self.num_actions, self.state_dim).to(device)
        self.target_network = Qnet(self.num_actions, self.state_dim).to(device)
        self.update_target_network()

        # Optimizer and loss function
        self.optimizer = optim.Adam(self.model.parameters(), lr=hyperparams['learning_rate'])
        self.criterion = nn.MSELoss()
        
        # Additional hyperparameters
        self.discount = hyperparams['discount_factor']
        self.epsilon = hyperparams['epsilon_max']
        self.epsilon_min = hyperparams['epsilon_min']
        self.epsilon_decay = hyperparams['epsilon_decay']
        self.clip_grad_norm = hyperparams['clip_grad_norm']
        self.loss_history = []
        self.running_loss = 0
        self.learned_counts = 0

    def select_action(self, state):
        """
        Select an action using epsilon-greedy policy
        """
        if np.random.random() < self.epsilon:
            return self.env.action_space.sample()
        with torch.no_grad():
            Q_values = self.model(state)
            return torch.argmax(Q_values).item()

    def learn(self, batch_size, done):
        """
        Learn from a batch of experiences using the DQN update rule
        """
        # Sample a batch from the replay buffer
        states, actions, next_states, rewards, dones = self.replay_memory.sample(batch_size)
        actions = actions.unsqueeze(1)
        rewards = rewards.unsqueeze(1)
        dones = dones.unsqueeze(1)
        
        # Compute predicted Q-values and target Q-values
        predicted_q = self.model(states).gather(dim=1, index=actions)
        with torch.no_grad():
            next_target_q_value = self.target_network(next_states).max(dim=1, keepdim=True)[0]
        next_target_q_value[dones] = 0
        y_js = rewards + (self.discount * next_target_q_value)
        
        # Compute loss
        loss = self.criterion(predicted_q, y_js)
        self.running_loss += loss.item()
        self.learned_counts += 1
        if done:
            self.loss_history.append(self.running_loss / self.learned_counts)
            self.running_loss, self.learned_counts = 0, 0
        
        # Backpropagate the loss
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.clip_grad_norm)
        self.optimizer.step()

    def update_target_network(self):
        """
        Update the target network by copying weights from the main network
        """
        self.target_network.load_state_dict(self.model.state_dict())

    def update_epsilon(self):
        """
        Update epsilon value for epsilon-greedy policy
        """
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def save(self, path):
        """
        Save the trained model
        """
        torch.save(self.model.state_dict(), path)
    
    def load(self, path):
        """
        Load the trained model
        """
        self.model.load_state_dict(torch.load(path, map_location=device))

# %%
# Trainer Class
class Trainer:
    def __init__(self, env, agent, hyperparams):
        """
        Trainer class to manage training and evaluation of the agent
        """
        self.env = env
        self.agent = agent
        self.hyperparams = hyperparams
        self.reward_history = []
        self.step_history = []
        if hasattr(agent, 'replay_memory'):
            self.use_replay_memory = True
        else:
            self.use_replay_memory = False

    def state_preprocess(self, state):
        """
        Convert the state to one-hot representation 
        """
        onehot_vector = torch.zeros(self.env.observation_space.n, dtype=torch.float32, device=device)
        onehot_vector[state] = 1
        return onehot_vector

    def train(self):
        """
        Train the agent for a specified number of episodes
        """
        total_steps = 0
        for episode in range(1, self.hyperparams['max_episodes'] + 1):
            state, _ = self.env.reset(seed=seed)
            state = self.state_preprocess(state)
            done, truncation = False, False
            step_size, episode_reward = 0, 0

            while not done and not truncation:
                # Select and execute an action
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)
                next_state = self.state_preprocess(next_state)

                # use ReplayBuffer
                if self.use_replay_memory:
                    self.agent.replay_memory.store(state, action, next_state, reward, done)
                    if len(self.agent.replay_memory) > self.hyperparams['batch_size'] and sum(self.reward_history) > 0:
                        self.agent.learn(self.hyperparams['batch_size'], (done or truncation))
                        # Update target network periodically
                        if total_steps % self.hyperparams['update_frequency'] == 0:
                            self.agent.update_target_network()

                state = next_state
                episode_reward += reward
                step_size += 1

            self.reward_history.append(episode_reward)
            self.step_history.append(step_size)  # Track steps for each episode
            total_steps += step_size
            self.agent.update_epsilon()

            # Save the model at specified intervals
            if episode % self.hyperparams['save_interval'] == 0:
                os.makedirs(self.hyperparams['model_dir'], exist_ok=True)
                self.agent.save(os.path.join(self.hyperparams['model_dir'], f'{episode}.pth'))
                print('\n~~~~~~Interval Save: Model saved.\n')
            # Print episode information at specified intervals
            if episode % self.hyperparams['print_interval'] == 0:
                print(f"Episode: {episode}, Total Steps: {total_steps}, Ep Step: {step_size}, Raw Reward: {episode_reward:.2f}, Epsilon: {self.agent.epsilon:.2f}")
        self.plot_training(episode)

    def test(self, max_episodes=None):
        """
        Test the trained agent
        """
        # Load the trained model
        self.agent.load(os.path.join(self.hyperparams['model_dir'], f"{self.hyperparams['train_episodes']}.pth"))
        self.agent.model.eval()

        if max_episodes is None:
            max_episodes = self.hyperparams['max_episodes']

        for episode in range(1, max_episodes + 1):
            state, _ = self.env.reset(seed=seed)
            done, truncation = False, False
            step_size, episode_reward = 0, 0

            while not done and not truncation:
                # Select an action
                state = self.state_preprocess(state)
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)
                state = next_state
                episode_reward += reward
                step_size += 1

            # Print episode information
            print(f"Episode: {episode}, Steps: {step_size}, Reward: {episode_reward:.2f}")


    def plot_training(self, episode):
        """
        Plot the training reward history, loss history, and step convergence
        """
        # Plot Rewards
        sma = np.convolve(self.reward_history, np.ones(50)/50, mode='valid')
        plt.figure()
        plt.title("Rewards")
        plt.plot(self.reward_history, label='Raw Reward', color='#F6CE3B', alpha=1)
        plt.plot(sma, label='SMA 50', color='#385DAA')
        plt.xlabel("Episode")
        plt.ylabel("Rewards")
        plt.legend()
        if episode == self.hyperparams['max_episodes']:
            os.makedirs(self.hyperparams['plot_dir'], exist_ok=True)
            plt.savefig(os.path.join(self.hyperparams['plot_dir'], 'reward_plot.png'), format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()

        # Plot Loss
        plt.figure()
        plt.title("Loss")
        plt.plot(self.agent.loss_history, label='Loss', color='#CB291A', alpha=1)
        plt.xlabel("Episode")
        plt.ylabel("Loss")
        if episode == self.hyperparams['max_episodes']:
            plt.savefig(os.path.join(self.hyperparams['plot_dir'], 'loss_plot.png'), format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()

        # Plot Steps Convergence
        sma_steps = np.convolve(self.step_history, np.ones(50)/50, mode='valid')
        plt.figure()
        plt.title("Steps Convergence")
        plt.plot(self.step_history, label='Raw Steps', color='#4CAF50', alpha=1)
        plt.plot(sma_steps, label='SMA 50', color='#FF5733')
        plt.xlabel("Episode")
        plt.ylabel("Steps")
        plt.legend()
        if episode == self.hyperparams['max_episodes']:
            plt.savefig(os.path.join(self.hyperparams['plot_dir'], 'steps_plot.png'), format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()

# %% [markdown]
# We first tested with hyperparameters set to the default value of traditional DQN, and we evaluated its performance with the avergae reward of the last 100 traning episodes:

# %%
# Main Function to Set Up and Train/Test the Model
if __name__ == "__main__":
    method_name = "dueling_dqn"
    train_mode = True

    train_episodes = 10000 
    render = not train_mode
    map_size = 4 # Start with 4x4 map
    seed = 1

    # build config
    config = {
        "train_mode": train_mode,
        "method_name": method_name,
        "model_dir": f'output/{method_name}/model/{map_size}x{map_size}/',
        "plot_dir": f'output/{method_name}/plt/{map_size}x{map_size}/',
        "save_interval": 500,
        "print_interval": 100,
        "clip_grad_norm": 3,
        "learning_rate": 6e-4 , 
        "discount_factor": 0.93,  
        "batch_size": 32,
        "update_frequency": 10,
        "max_episodes": train_episodes if train_mode else 10,
        "train_episodes": train_episodes,
        "max_steps": 200,
        "render": render,
        "epsilon_max": 0.9 if train_mode else -1, #0.999
        "epsilon_min": 0.01,
        "epsilon_decay": 0.999,
        "memory_capacity": 4000 if train_mode else 0,
        "map_size": map_size,
        "render_fps": 6,
    }

    # set seed
    seed_everything(seed)

    # Create environment
    env = gym.make(
        'FrozenLake-v1', 
        map_name=f"{config['map_size']}x{config['map_size']}", 
        is_slippery=True, 
        max_episode_steps=config['max_steps'], 
        render_mode="human" if config['render'] else None)

    env.reset(seed=seed)
    env.action_space.seed(seed)
    env.metadata['render_fps'] = config['render_fps']

    # Create agent and trainer
    agent = DQNAgent(env, config)
    trainer = Trainer(env, agent, config)

    # Train or test
    if config['train_mode']:
        trainer.train()
    else:
        trainer.test()
    avg_reward = np.mean(trainer.reward_history[-100:])
    print(f"Average reward of last 100 episodes: {avg_reward}")
# Out:
# Episode: 100, Total Steps: 718, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.81
# Episode: 200, Total Steps: 1544, Ep Step: 16, Raw Reward: 0.00, Epsilon: 0.74
# Episode: 300, Total Steps: 2489, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.67
# Episode: 400, Total Steps: 3382, Ep Step: 15, Raw Reward: 0.00, Epsilon: 0.60
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 500, Total Steps: 4323, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.55
# Episode: 600, Total Steps: 5437, Ep Step: 7, Raw Reward: 0.00, Epsilon: 0.49
# Episode: 700, Total Steps: 6588, Ep Step: 24, Raw Reward: 0.00, Epsilon: 0.45
# Episode: 800, Total Steps: 7673, Ep Step: 14, Raw Reward: 0.00, Epsilon: 0.40
# Episode: 900, Total Steps: 8743, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.37
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1000, Total Steps: 9983, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.33
# Episode: 1100, Total Steps: 11368, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.30
# Episode: 1200, Total Steps: 12777, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.27
# Episode: 1300, Total Steps: 14028, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.25
# Episode: 1400, Total Steps: 15410, Ep Step: 16, Raw Reward: 1.00, Epsilon: 0.22
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1500, Total Steps: 16672, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.20
# Episode: 1600, Total Steps: 18267, Ep Step: 13, Raw Reward: 0.00, Epsilon: 0.18
# Episode: 1700, Total Steps: 19643, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.16
# Episode: 1800, Total Steps: 20996, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.15
# Episode: 1900, Total Steps: 22606, Ep Step: 23, Raw Reward: 1.00, Epsilon: 0.13
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2000, Total Steps: 23945, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.12
# Episode: 2100, Total Steps: 25422, Ep Step: 33, Raw Reward: 1.00, Epsilon: 0.11
# Episode: 2200, Total Steps: 26513, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.10
# Episode: 2300, Total Steps: 27703, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.09
# Episode: 2400, Total Steps: 28911, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.08
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2500, Total Steps: 29984, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.07
# Episode: 2600, Total Steps: 31165, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.07
# Episode: 2700, Total Steps: 32080, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.06
# Episode: 2800, Total Steps: 33027, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.05
# Episode: 2900, Total Steps: 33981, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.05
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3000, Total Steps: 34993, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.04
# Episode: 3100, Total Steps: 35801, Ep Step: 41, Raw Reward: 1.00, Epsilon: 0.04
# Episode: 3200, Total Steps: 36578, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.04
# Episode: 3300, Total Steps: 37424, Ep Step: 41, Raw Reward: 1.00, Epsilon: 0.03
# Episode: 3400, Total Steps: 38216, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.03
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3500, Total Steps: 38984, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.03
# Episode: 3600, Total Steps: 40024, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3700, Total Steps: 40810, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3800, Total Steps: 41648, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3900, Total Steps: 42368, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.02
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4000, Total Steps: 43192, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 4100, Total Steps: 43971, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4200, Total Steps: 44744, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4300, Total Steps: 45492, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4400, Total Steps: 46172, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4500, Total Steps: 46993, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4600, Total Steps: 47766, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 4700, Total Steps: 48440, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4800, Total Steps: 49179, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4900, Total Steps: 49921, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5000, Total Steps: 50818, Ep Step: 41, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5100, Total Steps: 51584, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5200, Total Steps: 52314, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5300, Total Steps: 52974, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5400, Total Steps: 53634, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5500, Total Steps: 54420, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5600, Total Steps: 55176, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5700, Total Steps: 55903, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5800, Total Steps: 56631, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5900, Total Steps: 57371, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6000, Total Steps: 58067, Ep Step: 23, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6100, Total Steps: 58789, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6200, Total Steps: 59439, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6300, Total Steps: 60198, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6400, Total Steps: 60930, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6500, Total Steps: 61781, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6600, Total Steps: 62505, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6700, Total Steps: 63265, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6800, Total Steps: 63952, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6900, Total Steps: 64590, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7000, Total Steps: 65306, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7100, Total Steps: 66021, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7200, Total Steps: 66792, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7300, Total Steps: 67598, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7400, Total Steps: 68552, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7500, Total Steps: 69763, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7600, Total Steps: 71012, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7700, Total Steps: 72017, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7800, Total Steps: 72956, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
# Episode: 7900, Total Steps: 73863, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8000, Total Steps: 74590, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8100, Total Steps: 75413, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8200, Total Steps: 76120, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8300, Total Steps: 76850, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8400, Total Steps: 77536, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8500, Total Steps: 78228, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8600, Total Steps: 79014, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8700, Total Steps: 79725, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8800, Total Steps: 80429, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8900, Total Steps: 81238, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9000, Total Steps: 81946, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9100, Total Steps: 82684, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9200, Total Steps: 83445, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9300, Total Steps: 84292, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9400, Total Steps: 85140, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9500, Total Steps: 86019, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9600, Total Steps: 86952, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9700, Total Steps: 87748, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9800, Total Steps: 88467, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9900, Total Steps: 89132, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 10000, Total Steps: 90058, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Average reward of last 100 episodes: 0.83

# %% [markdown]
# ## 2. Repetition of the best performance
# Hyperparameter values after the "#" are default values of traditional DQN，here we modify them for better performance.
#
# Here they are set to be the combination with best preformance.
#
# The best performance of the model is to achieve the average SMA 50 reward of 0.93 in the last 100 episodes.

# %%
# Main Function to Set Up and Train/Test the Model
if __name__ == "__main__":
    method_name = "dueling_dqn"
    train_mode = True

    train_episodes = 10000 
    render = not train_mode
    map_size = 4 # Start with 4x4 map
    seed = 1

    # build config
    config = {
        "train_mode": train_mode,
        "method_name": method_name,
        "model_dir": f'output/{method_name}/model/{map_size}x{map_size}/',
        "plot_dir": f'output/{method_name}/plt/{map_size}x{map_size}/',
        "save_interval": 500,
        "print_interval": 100,
        "clip_grad_norm": 3,
        "learning_rate": 5e-4 , #6e-4 
        "discount_factor": 0.9,  #0.93
        "batch_size": 32,
        "update_frequency": 10,
        "max_episodes": train_episodes if train_mode else 10,
        "train_episodes": train_episodes,
        "max_steps": 200,
        "render": render,
        "epsilon_max": 0.9 if train_mode else -1, #0.999
        "epsilon_min": 0.01,
        "epsilon_decay": 0.999,
        "memory_capacity": 4000 if train_mode else 0,
        "map_size": map_size,
        "render_fps": 6,
    }

    # set seed
    seed_everything(seed)

    # Create environment
    env = gym.make(
        'FrozenLake-v1', 
        map_name=f"{config['map_size']}x{config['map_size']}", 
        is_slippery=True, 
        max_episode_steps=config['max_steps'], 
        render_mode="human" if config['render'] else None)

    env.reset(seed=seed)
    env.action_space.seed(seed)
    env.metadata['render_fps'] = config['render_fps']

    # Create agent and trainer
    agent = DQNAgent(env, config)
    trainer = Trainer(env, agent, config)

    # Train or test
    if config['train_mode']:
        trainer.train()
    else:
        trainer.test()
    avg_reward = np.mean(trainer.reward_history[-100:])
    print(f"Best Performance with average reward of last 100 episodes: {avg_reward}")
# Out:
# Episode: 100, Total Steps: 718, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.81
# Episode: 200, Total Steps: 1512, Ep Step: 10, Raw Reward: 0.00, Epsilon: 0.74
# Episode: 300, Total Steps: 2486, Ep Step: 32, Raw Reward: 1.00, Epsilon: 0.67
# Episode: 400, Total Steps: 3417, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.60
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 500, Total Steps: 4312, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.55
# Episode: 600, Total Steps: 5163, Ep Step: 3, Raw Reward: 0.00, Epsilon: 0.49
# Episode: 700, Total Steps: 6104, Ep Step: 12, Raw Reward: 0.00, Epsilon: 0.45
# Episode: 800, Total Steps: 7322, Ep Step: 31, Raw Reward: 0.00, Epsilon: 0.40
# Episode: 900, Total Steps: 8353, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.37
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1000, Total Steps: 9624, Ep Step: 19, Raw Reward: 0.00, Epsilon: 0.33
# Episode: 1100, Total Steps: 11116, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.30
# Episode: 1200, Total Steps: 12518, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.27
# Episode: 1300, Total Steps: 14025, Ep Step: 8, Raw Reward: 0.00, Epsilon: 0.25
# Episode: 1400, Total Steps: 15479, Ep Step: 4, Raw Reward: 0.00, Epsilon: 0.22
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1500, Total Steps: 16928, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.20
# Episode: 1600, Total Steps: 18396, Ep Step: 9, Raw Reward: 1.00, Epsilon: 0.18
# Episode: 1700, Total Steps: 19830, Ep Step: 12, Raw Reward: 1.00, Epsilon: 0.16
# Episode: 1800, Total Steps: 21324, Ep Step: 5, Raw Reward: 0.00, Epsilon: 0.15
# Episode: 1900, Total Steps: 22948, Ep Step: 30, Raw Reward: 0.00, Epsilon: 0.13
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2000, Total Steps: 24362, Ep Step: 23, Raw Reward: 1.00, Epsilon: 0.12
# Episode: 2100, Total Steps: 25871, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.11
# Episode: 2200, Total Steps: 27297, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.10
# Episode: 2300, Total Steps: 28556, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.09
# Episode: 2400, Total Steps: 29688, Ep Step: 23, Raw Reward: 1.00, Epsilon: 0.08
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 2500, Total Steps: 30770, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.07
# Episode: 2600, Total Steps: 31721, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.07
# Episode: 2700, Total Steps: 32669, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.06
# Episode: 2800, Total Steps: 33589, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.05
# Episode: 2900, Total Steps: 34571, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.05
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3000, Total Steps: 35391, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.04
# Episode: 3100, Total Steps: 36278, Ep Step: 33, Raw Reward: 1.00, Epsilon: 0.04
# Episode: 3200, Total Steps: 37309, Ep Step: 23, Raw Reward: 1.00, Epsilon: 0.04
# Episode: 3300, Total Steps: 38186, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.03
# Episode: 3400, Total Steps: 39060, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.03
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 3500, Total Steps: 39874, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.03
# Episode: 3600, Total Steps: 40667, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3700, Total Steps: 41530, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3800, Total Steps: 42292, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 3900, Total Steps: 43069, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.02
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4000, Total Steps: 43836, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.02
# Episode: 4100, Total Steps: 44656, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4200, Total Steps: 45346, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4300, Total Steps: 46145, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4400, Total Steps: 46887, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 4500, Total Steps: 47649, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4600, Total Steps: 48362, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4700, Total Steps: 49086, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4800, Total Steps: 49737, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 4900, Total Steps: 50401, Ep Step: 6, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5000, Total Steps: 51170, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5100, Total Steps: 51903, Ep Step: 23, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5200, Total Steps: 52751, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5300, Total Steps: 53499, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5400, Total Steps: 54279, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 5500, Total Steps: 55000, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5600, Total Steps: 55866, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5700, Total Steps: 56669, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5800, Total Steps: 57415, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 5900, Total Steps: 58135, Ep Step: 23, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6000, Total Steps: 58898, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6100, Total Steps: 59653, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6200, Total Steps: 60419, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6300, Total Steps: 61159, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6400, Total Steps: 61834, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 6500, Total Steps: 62535, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6600, Total Steps: 63279, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6700, Total Steps: 63982, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6800, Total Steps: 64720, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 6900, Total Steps: 65434, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7000, Total Steps: 66109, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7100, Total Steps: 66850, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7200, Total Steps: 67612, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7300, Total Steps: 68444, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7400, Total Steps: 69283, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 7500, Total Steps: 69973, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7600, Total Steps: 70706, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7700, Total Steps: 71537, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7800, Total Steps: 72358, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 7900, Total Steps: 73163, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8000, Total Steps: 73876, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8100, Total Steps: 74588, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8200, Total Steps: 75317, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8300, Total Steps: 75986, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8400, Total Steps: 76724, Ep Step: 11, Raw Reward: 0.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 8500, Total Steps: 77558, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8600, Total Steps: 78312, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8700, Total Steps: 79069, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8800, Total Steps: 79820, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 8900, Total Steps: 80512, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9000, Total Steps: 81382, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9100, Total Steps: 82165, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9200, Total Steps: 82960, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9300, Total Steps: 83742, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9400, Total Steps: 84599, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 9500, Total Steps: 85441, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9600, Total Steps: 86166, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9700, Total Steps: 86863, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9800, Total Steps: 87597, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
# Episode: 9900, Total Steps: 88384, Ep Step: 6, Raw Reward: 1.00, Epsilon: 0.01
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 10000, Total Steps: 89073, Ep Step: 2, Raw Reward: 0.00, Epsilon: 0.01
# Best Performance with average reward of last 100 episodes: 0.93
